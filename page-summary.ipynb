# %%
# load Dependancies
from __future__ import absolute_import
from __future__ import division, print_function, unicode_literals
from sumy.parsers.html import HtmlParser
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer as Summarizer
from sumy.nlp.stemmers import Stemmer
from sumy.utils import get_stop_words
import pandas as pd
df=pd.read_csv('/home/hotelsng/Downloads/valid_websites.csv')
df.head()


if __name__ == "__main__":
    def getSummary():
        SENTENCES_COUNT=3
        for index, url in df.iterrows():
            try:
                url= url["valid_website"]
                print(url)
                parser = HtmlParser.from_url(url, Tokenizer('english'))
                stemmer = Stemmer('english')
                summarizer = Summarizer(stemmer)
                summarizer.stop_words = get_stop_words('english')
                for sentence in summarizer(parser.document, SENTENCES_COUNT):
                    print(sentence)
                df.to_csv("summary.csv")
                print('\n')
            except:
                print("Must be a network issue. Try again later")
                print('\n')

# %%
getSummary()
# Out:
# https://www.khwattu.org/
# "!Khwa ttu builds a bridge between the past & the future...""Once we were proud hunters and later we were hunted.
# Environmental programmes Share in the San way of life in the Cape Floral Region World Heritage Site.
# As a unique travel destination and training centre, !Khwa ttu combines culture and heritage, adventure and relaxation, and education, giving a new understanding of the phrase “San Spirit Shared”.
#
#
# http://www.tchorniy-accommodation.blogspot.com/
# We are 1000 meters away from Uvongo swimming beach and bathing area.We have a beautiful lagoon, all of which are under the watchful eye of lifeguards.
# Our units consists of two bedroom, bathroom, large entertaining area, parking bays for 2 vehicles with a section for a trailer.
# Items provided in the units are: Kitchen: Microwave, stove, fridge/freezer, kettle, cutlery, crockery
# Lounge: TV with DSTV Compact.
#
#
# http://www.kosibayprivatelodge.co.za/
# ...

# %%
for index, url in df.iterrows():
        #print(url["valid_website"])

     try:
            parser = HtmlParser.from_url(url["valid_website"], Tokenizer('english'))
            stemmer = Stemmer('english')

            summarizer = Summarizer(stemmer)
            summarizer.stop_words = get_stop_words('english')

            for sentence in summarizer(parser.document, SENTENCES_COUNT=3):
               print(sentence)

    except:
           prin
